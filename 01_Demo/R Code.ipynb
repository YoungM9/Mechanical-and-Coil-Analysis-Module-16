# %%
R --version
install.package("tidyverse")
install.packages("tidyverse")
setwd("C:/Users/nextg/Desktop/Data Analysis/Module Assignments/Module Assignments/Module 16/R Analysis")
setwd("C:/Users/nextg/Desktop/Data Analysis/Module Assignments/Module Assignments/Module 16/R Analysis")
setwd("C:/Users/nextg/Desktop/Data Analysis/Module Assignments/Module Assignments/Module 16/R Analysis")
x <- 3
y <- 10
x
x + y
numlist <- c(0,1,2,3,4,5)
demo_table <- read.csv(file='demo.csv',check.names=F,stringsAsFactors = F)
data <- read.csv("demo.csv")
demo_table <- read.csv(file='demo.csv',check.names=F,stringsAsFactors = F)
setwd("C:/Users/nextg/Desktop/Data Analysis/Module Assignments/Module Assignments/Module 16/R Analysis/01_Demo")
demo_table <- read.csv(file='demo.csv',check.names=F,stringsAsFactors = F)
# ?from(JSON)
library(jsonlite)
# ?fromJSON()
dem_table2 <- fromJSON(txt='demo.json')
demo_table[3,"Year"]
demo_table[3,3]
demo_table$"Vehicle_Class"
demo_table["Year"]
demo_table[2,"Year"]
demo_table[1,"Year"]
filter_table <- demo_table[demo_table$price > 10000,]
filter_table2 <-- demo_table[demo_table$price >500,]
filter_table2 <-- demo_table[demo_table$price > 20000,]
filter_table2 <- demo_table[demo_table$price > 2000,]
filter_price <- demo_table[demo_table$price > 500,]
filter_price2 <- demo_table[demo_table$price > 800,]
subset_price <- demo_table2[("clean" %in% demo_table2$title_status) & demo_table2$price > 10000]
subset_price <- dem_table2[("clean" %in% dem_table2$title_status) & (dem_table2$pric > 10000)]
subset_price2 <- dem_table2[("gas" %in% dem_table2$fuel) & (dem_table2$price > 10000)]
# ?sample()
sample(c("Cow", "chicken", "deer", "pig", "sheep"))
sample(c("cow", "giraffe", "penguin", "dog", "cat"), 3)
animal_sample < - sample(c("goat", "mountain_goat", "sheep"), 1)
demo_table[sample(1:nrow(demo_table), 3),]
demo_table <- demo_table %>% mutate(Mileage_per_Year=Total_Miles/(2020-Yea), IsActive=TRUE) #Add columns to the dataframe
library(tidyverse)
# ?mutate()
emo_table <- demo_table %>% mutate(Mileage_per_Year=Total_Miles/(2020-Yea), IsActive=TRUE) #Add columns to the dataframe
> summarize_demo <- demo_table2 %>% group_by(condition) %>% summarize(Mean_Mileage=mean(odometer), .groups = 'keep') #create summary table
summarize_demo <- demo_table2 %>% group_by(condition) %>% summarize(Mean_Mileage=mean(odometer), .groups = 'keep') #create summary table
> demo_table3 <- read.csv('demo2.csv',check.names = F,stringsAsFactors = F)
demo_table3 <- read.csv('demo2.csv',check.names = F,stringsAsFactors = F)
rlang::last_error()
long_table <- gather(demo_table3,key="Metric",value="Score",buying_price:popularity)
View(long_table)
View(long_table)
View(demo_table3)
View(demo_table3)
View(long_table)
View(long_table)
# ?spread()
wide_table <- long_table %>% spread(key="Metric", value="Score")
View(wide_table)
View(wide_table)
all.equal()
ggplot()
# ?ggplot()
head(mpg)
plt <- ggplot(mpg,aes(x=class)) #import dataset into ggplot2
plt + geom_bar() #plot a bar plot
mpg_summary <- mpg %>% group_by(manufacturer) %>% summarize(Vehicle_Count=n(), .groups = 'keep') #create summary tableplt <- ggplot(mpg_summary,aes(x=manufacturer,y=Vehicle_Count)) #import dataset into ggplot2
> plt + geom_col() #plot a bar plot
mpg_summary <- mpg %>% group_by(manufacturer) %>% sumamrize(Vehicle_Count=n(), .groups = "keep") #create summary table
mpg_summary <- mpg %>% group_by(manufacturer) %>% summarize(Vehicle_Count=n(), .groups = 'keep') #create summary table
plt <- ggplot(mpg_summary,aes(x=manufacturer,y=Vehicle_Count)) #import dataset into ggplot2
plt + geom_col() #plot a bar plot
plt + geom_col() + xlab("Manufacturing Company") + ylab("Number of Vehicles in Dataset") #plot bar plot with labels
theme(axis.text.x=element_text(angle=45,hjust=1)) #rotate the x-axis label 45 degrees
plt + geom_line()
mpg_summary <- subset(mpg,manufacturer=="toyota") %>% group_by(cyl) %>% summarize(Mean_Hwy=mean(hwy), .groups = 'keep') #create summary table
plt <- ggplot(mpg_summary,aes(x=cyl,y=Mean_Hwy)) #import dataset into ggplot2
plt + geom_line()
plt <- ggplot(mpg,aes(x=displ,y=cty)) #import dataset into ggplot2
plt + geom_point() + xlab("Engine Size (L)") + ylab("City Fuel-Efficiency (MPG)") #add scatter plot with labels
ggplot(mtcars,aes(x=wt)) + geom_density() #visualize distribution using density plot
shapiro.test()
# ?shapiro.test()
shapiro.test(mtcars$wt)
# ?sample_n()
population_table <- rad.csv("used_car_data.csv",check.names = F,stringsAsFactors = F) #import used car dataset
population_table <- read.csv("used_car_data.csv",check.names = F,stringsAsFactors = F) #import the data
population_data <- read.csv("Vehicle_Data", check.names =  F,stringsAsFactors = F) #import used car dataset
setwd("C:/Users/nextg/Desktop/Data Analysis/Module Assignments/Module Assignments/Module 16/R Analysis/01_Demo")
population_data <- read.csv("Vehicle_Data.csv", check.names = F,stringsAsFactors = F)
# ?t.test
# ?aov()
